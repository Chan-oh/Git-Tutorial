# %% [markdown]
# <a href="https://colab.research.google.com/github/Chan-oh/Git-Tutorial/blob/master/%EA%B7%B8%EB%A3%B9%ED%99%94_%EC%9E%91%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 데이터 읽기
data = pd.io.stata.read_stata('/content/drive/My Drive/t-project/lendingclub.dta')

# %%
data['purpose2'].unique()
# Out:
# array([0, 1], dtype=int8)

# %% [markdown]
# # **데이터 추출 : 대출목적 추출**

# %%
p1 = data['purpose2'] == 1 
p2 = data['purpose3'] == 1
data = data[p1 | p2]

# %% [markdown]
# #**2. state 별 분석**

# %%
#새로운 컬럼(state) 생성
data['state'] = ""
data
# Out:
#          loan_amnt  funded_amnt  ...  mths_since_recent_revol_delinq11  state
# 0            19000        19000  ...                                 0
# 1            10000        10000  ...                                 0
# 2             6000         6000  ...                                 0
# 3            25200        25200  ...                                 0
# 5            20000        20000  ...                                 1
# ...            ...          ...  ...                               ...    ...
# 1092913      12000        12000  ...                                 0
# 1092915      10000        10000  ...                                 0
# 1092916      12000        12000  ...                                 0
# 1092917      13000        13000  ...                                 0
# 1092918      20000        20000  ...                                 0
#
# [883563 rows x 334 columns]

# %% [markdown]
# ## **state 변수에 주 이름과 gdp 순위 값 넣기**

# %%
#주 이름과 gdp 순위 입력
data['addr_state1']=data['addr_state1'].replace({1:'AK(9)', 0:''}) 
data['addr_state2']=data['addr_state2'].replace({1:'AL(48)', 0:''}) 
data['addr_state3']=data['addr_state3'].replace({1:'AR(49)', 0:''}) 
data['addr_state4']=data['addr_state4'].replace({1:'AZ(40)', 0:''}) 
data['addr_state5']=data['addr_state5'].replace({1:'CA(6)', 0:''}) 
data['addr_state6']=data['addr_state6'].replace({1:'CO(13)', 0:''}) 
data['addr_state7']=data['addr_state7'].replace({1:'CT(5)', 0:''}) 
data['addr_state8']=data['addr_state8'].replace({1:'DC(1)', 0:''}) 
data['addr_state9']=data['addr_state9'].replace({1:'DE(7)', 0:''}) 
data['addr_state10']=data['addr_state10'].replace({1:'FL(39)', 0:''}) 
data['addr_state11']=data['addr_state11'].replace({1:'GA(29)', 0:''}) 
data['addr_state12']=data['addr_state12'].replace({1:'HI(16)', 0:''}) 
data['addr_state13']=data['addr_state13'].replace({1:'IA(23)', 0:''}) 
data['addr_state14']=data['addr_state14'].replace({1:'ID(47)', 0:''}) 
data['addr_state15']=data['addr_state15'].replace({1:'IL(12)', 0:''}) 
data['addr_state16']=data['addr_state16'].replace({1:'IN(33)', 0:''}) 
data['addr_state17']=data['addr_state17'].replace({1:'KS(25)', 0:''}) 
data['addr_state18']=data['addr_state18'].replace({1:'KY(45)', 0:''}) 
data['addr_state19']=data['addr_state19'].replace({1:'LA(36)', 0:''}) 
data['addr_state20']=data['addr_state20'].replace({1:'MA(3)', 0:''}) 
data['addr_state21']=data['addr_state21'].replace({1:'MD(11)', 0:''}) 
data['addr_state22']=data['addr_state22'].replace({1:'ME(41)', 0:''}) 
data['addr_state23']=data['addr_state23'].replace({1:'MI(38)', 0:''}) 
data['addr_state24']=data['addr_state24'].replace({1:'MN(15)', 0:''}) 
data['addr_state25']=data['addr_state25'].replace({1:'MO(37)', 0:''}) 
data['addr_state26']=data['addr_state26'].replace({1:'MS(51)', 0:''}) 
data['addr_state27']=data['addr_state27'].replace({1:'MT(42)', 0:''}) 
data['addr_state28']=data['addr_state28'].replace({1:'NC(32)', 0:''}) 
data['addr_state29']=data['addr_state29'].replace({1:'ND(8)', 0:''}) 
data['addr_state30']=data['addr_state30'].replace({1:'NE(14)', 0:''}) 
data['addr_state31']=data['addr_state31'].replace({1:'NH(19)', 0:''}) 
data['addr_state32']=data['addr_state32'].replace({1:'NJ(10)', 0:''}) 
data['addr_state33']=data['addr_state33'].replace({1:'NM(43)', 0:''}) 
data['addr_state34']=data['addr_state34'].replace({1:'NV(31)', 0:''}) 
data['addr_state35']=data['addr_state35'].replace({1:'NY(2)', 0:''}) 
data['addr_state36']=data['addr_state36'].replace({1:'OH(28)', 0:''}) 
data['addr_state37']=data['addr_state37'].replace({1:'OK(44)', 0:''}) 
data['addr_state38']=data['addr_state38'].replace({1:'OR(24)', 0:''}) 
data['addr_state39']=data['addr_state39'].replace({1:'PA(21)', 0:''}) 
data['addr_state40']=data['addr_state40'].replace({1:'RI(30)', 0:''}) 
data['addr_state41']=data['addr_state41'].replace({1:'SC(46)', 0:''}) 
data['addr_state42']=data['addr_state42'].replace({1:'SD(20)', 0:''}) 
data['addr_state43']=data['addr_state43'].replace({1:'TN(34)', 0:''}) 
data['addr_state44']=data['addr_state44'].replace({1:'TX(22)', 0:''}) 
data['addr_state45']=data['addr_state45'].replace({1:'UT(26)', 0:''}) 
data['addr_state46']=data['addr_state46'].replace({1:'VA(18)', 0:''}) 
data['addr_state47']=data['addr_state47'].replace({1:'VT(35)', 0:''}) 
data['addr_state48']=data['addr_state48'].replace({1:'WA(4)', 0:''}) 
data['addr_state49']=data['addr_state49'].replace({1:'WI(27)', 0:''}) 
data['addr_state50']=data['addr_state50'].replace({1:'WV(50)', 0:''}) 
data['addr_state51']=data['addr_state51'].replace({1:'WY(17)', 0:''})
data['state'] = data['addr_state1'] + data['addr_state2'] + data['addr_state3'] + data['addr_state4'] + data['addr_state5'] + data['addr_state6'] + data['addr_state7'] + data['addr_state8'] + data['addr_state9'] + data['addr_state10']+ data['addr_state11'] + data['addr_state12']+ data['addr_state13'] + data['addr_state14']+ data['addr_state15'] + data['addr_state16']+ data['addr_state17'] + data['addr_state18']+ data['addr_state19'] + data['addr_state20']+ data['addr_state21'] + data['addr_state22']+ data['addr_state23'] + data['addr_state24']+ data['addr_state25'] + data['addr_state26']+ data['addr_state27'] + data['addr_state28']+ data['addr_state29'] + data['addr_state30']+ data['addr_state31'] + data['addr_state32']+ data['addr_state33'] + data['addr_state34']+ data['addr_state35'] + data['addr_state36']+ data['addr_state37'] + data['addr_state38']+ data['addr_state39'] + data['addr_state40']+ data['addr_state41'] + data['addr_state42']+ data['addr_state43'] + data['addr_state44']+ data['addr_state45'] + data['addr_state46']+ data['addr_state47'] + data['addr_state48']+ data['addr_state49'] + data['addr_state50']+ data['addr_state51']
data['state'].unique()
# Out:
# array(['CA(6)', 'FL(39)', 'MN(15)', 'AZ(40)', 'TN(34)', 'KY(45)',
#        'TX(22)', 'AL(48)', 'GA(29)', 'VA(18)', 'IN(33)', 'DC(1)',
#        'SC(46)', 'PA(21)', 'WI(27)', 'NH(19)', 'WA(4)', 'NJ(10)',
#        'CO(13)', 'OK(44)', 'MD(11)', 'MO(37)', 'OH(28)', 'LA(36)',
#        'KS(25)', 'IL(12)', 'WY(17)', 'NY(2)', 'WV(50)', 'OR(24)',
#        'NC(32)', 'AR(49)', 'HI(16)', 'UT(26)', 'MA(3)', 'NV(31)',
#        'MI(38)', 'MS(51)', 'NM(43)', 'SD(20)', 'ND(8)', 'MT(42)',
#        'NE(14)', 'CT(5)', 'ID(47)', 'VT(35)', 'ME(41)', 'DE(7)', 'RI(30)',
#        'AK(9)', 'IA(23)'], dtype=object)

# %% [markdown]
# # **state로 그룹화 실시**

# %%
check = data.groupby(['state']).mean()

# %%
check
# Out:
#            loan_amnt  ...  mths_since_recent_revol_delinq11
# state                 ...
# AK(9)   16799.541495  ...                          0.036680
# AL(48)  14127.402002  ...                          0.034521
# AR(49)  13452.780757  ...                          0.031102
# AZ(40)  13782.876745  ...                          0.034280
# CA(6)   14527.543561  ...                          0.032943
# CO(13)  14397.775216  ...                          0.032650
# CT(5)   14697.589799  ...                          0.033679
# DC(1)   15375.631369  ...                          0.025698
# DE(7)   14230.570319  ...                          0.031480
# FL(39)  13514.428004  ...                          0.035423
# GA(29)  14567.206963  ...                          0.030519
# HI(16)  15332.872743  ...                          0.032093
# IA(23)   7200.000000  ...                          0.000000
# ID(47)  12638.497110  ...                          0.034682
# ...

# %%
check['gdp'] = ""
check
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# AK(9)   16799.541495  16799.541495  ...                          0.036680
# AL(48)  14127.402002  14127.399663  ...                          0.034521
# AR(49)  13452.780757  13452.780757  ...                          0.031102
# AZ(40)  13782.876745  13782.876745  ...                          0.034280
# CA(6)   14527.543561  14527.543366  ...                          0.032943
# CO(13)  14397.775216  14397.775216  ...                          0.032650
# CT(5)   14697.589799  14697.589799  ...                          0.033679
# DC(1)   15375.631369  15375.631369  ...                          0.025698
# DE(7)   14230.570319  14230.570319  ...                          0.031480
# FL(39)  13514.428004  13514.428004  ...                          0.035423
# GA(29)  14567.206963  14567.206963  ...                          0.030519
# ...

# %%
#gdp 순위 입력
add_lst = [9,48,49, 40, 6, 13, 5, 1, 7, 39, 29, 16, 23, 47, 12, 33, 25, 45, 36, 3, 11, 41, 38, 15, 37, 51, 42, 32, 8, 14, 19, 10, 43, 31, 2, 28, 44, 24, 21, 30, 46, 20, 34, 22, 26, 18, 35, 4, 27, 50, 17]
check["gdp"] = add_lst
check
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# AK(9)   16799.541495  16799.541495  ...                          0.036680    9
# AL(48)  14127.402002  14127.399663  ...                          0.034521   48
# AR(49)  13452.780757  13452.780757  ...                          0.031102   49
# AZ(40)  13782.876745  13782.876745  ...                          0.034280   40
# CA(6)   14527.543561  14527.543366  ...                          0.032943    6
# CO(13)  14397.775216  14397.775216  ...                          0.032650   13
# CT(5)   14697.589799  14697.589799  ...                          0.033679    5
# DC(1)   15375.631369  15375.631369  ...                          0.025698    1
# DE(7)   14230.570319  14230.570319  ...                          0.031480    7
# FL(39)  13514.428004  13514.428004  ...                          0.035423   39
# ...

# %%
#gdp 순위대로 정렬
df_sort_gdp = check.sort_values('gdp',ascending=True)
df_sort_gdp
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# DC(1)   15375.631369  15375.631369  ...                          0.025698    1
# NY(2)   14354.581949  14354.581949  ...                          0.025182    2
# MA(3)   15204.308591  15204.308591  ...                          0.030234    3
# WA(4)   14719.725415  14719.725415  ...                          0.030007    4
# CT(5)   14697.589799  14697.589799  ...                          0.033679    5
# CA(6)   14527.543561  14527.543366  ...                          0.032943    6
# DE(7)   14230.570319  14230.570319  ...                          0.031480    7
# ND(8)   13694.616877  13694.616877  ...                          0.029098    8
# AK(9)   16799.541495  16799.541495  ...                          0.036680    9
# NJ(10)  15199.448615  15199.448615  ...                          0.032199   10
# ...

# %%
#이상치 제거
gdp = df_sort_gdp.drop(index='IA(23)')
gdp
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# DC(1)   15375.631369  15375.631369  ...                          0.025698    1
# NY(2)   14354.581949  14354.581949  ...                          0.025182    2
# MA(3)   15204.308591  15204.308591  ...                          0.030234    3
# WA(4)   14719.725415  14719.725415  ...                          0.030007    4
# CT(5)   14697.589799  14697.589799  ...                          0.033679    5
# CA(6)   14527.543561  14527.543366  ...                          0.032943    6
# DE(7)   14230.570319  14230.570319  ...                          0.031480    7
# ND(8)   13694.616877  13694.616877  ...                          0.029098    8
# AK(9)   16799.541495  16799.541495  ...                          0.036680    9
# NJ(10)  15199.448615  15199.448615  ...                          0.032199   10
# ...

# %% [markdown]
# ###**gdp 순위로 정렬하여 데이터 살펴보기**

# %%
#gdp 순위로 정렬한 상태에서 부도율 확인해보기
plt.figure(figsize=(30,5))
plt.plot(gdp['depvar'], label='depvar', marker='o', markersize=5)
avg = float(np.mean(data['depvar']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %%
#gdp 순위로 정렬한 상태에서 annual_inc 확인해보기
plt.figure(figsize=(30,5))
plt.plot(gdp['annual_inc'], label='annual_inc')
plt.legend()
plt.show()

# %% [markdown]
# ###**부도율 순으로 정렬하여 살펴보기**

# %%
df_sort_dep = check.sort_values('depvar',ascending=True)
df_sort_dep
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# ME(41)  12854.279628  12854.279628  ...                          0.041053   41
# VT(35)  13361.317747  13361.317747  ...                          0.030818   35
# DC(1)   15375.631369  15375.631369  ...                          0.025698    1
# NH(19)  14253.586066  14253.586066  ...                          0.033698   19
# OR(24)  13303.357536  13303.357536  ...                          0.029584   24
# KS(25)  14209.607451  14209.607451  ...                          0.032100   25
# CO(13)  14397.775216  14397.775216  ...                          0.032650   13
# SC(46)  14240.295319  14240.295319  ...                          0.036084   46
# WA(4)   14719.725415  14719.725415  ...                          0.030007    4
# CT(5)   14697.589799  14697.589799  ...                          0.033679    5
# ...

# %%
dep = df_sort_dep.drop(index='IA(23)')
dep
# Out:
#            loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11  gdp
# state                               ...
# ME(41)  12854.279628  12854.279628  ...                          0.041053   41
# VT(35)  13361.317747  13361.317747  ...                          0.030818   35
# DC(1)   15375.631369  15375.631369  ...                          0.025698    1
# NH(19)  14253.586066  14253.586066  ...                          0.033698   19
# OR(24)  13303.357536  13303.357536  ...                          0.029584   24
# KS(25)  14209.607451  14209.607451  ...                          0.032100   25
# CO(13)  14397.775216  14397.775216  ...                          0.032650   13
# SC(46)  14240.295319  14240.295319  ...                          0.036084   46
# WA(4)   14719.725415  14719.725415  ...                          0.030007    4
# CT(5)   14697.589799  14697.589799  ...                          0.033679    5
# ...

# %%
#부도율 순으로 정렬한 것 시각화 : 전체 평균
plt.figure(figsize=(30,5))
plt.plot(dep['depvar'], label='depvar', marker='o', markersize=5)
avg = float(np.mean(data['depvar']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %%
#부도율 순으로 정렬한 것 시각화 : 이상치 제거 평균
plt.figure(figsize=(30,5))
plt.plot(dep['depvar'], label='depvar', marker='o', markersize=5)
avg = float(np.mean(dep['depvar']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %%
#부도율 순으로 정렬하여 gdp 살펴보기
plt.figure(figsize=(30,5))
plt.plot(dep['gdp'], label='gdp', marker='o', markersize=5)
avg = float(np.mean(dep['gdp']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ##**부도율의 평균 값을 기준으로 2그룹으로 나누어보기**

# %%
avg = float(np.mean(dep['depvar']))
dep_over = dep[dep['depvar'] >= avg]
dep_under = dep[dep['depvar'] < avg]

# %% [markdown]
# ##**1) GDP**

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_over['gdp'], label='gdp', marker='o', markersize=5)
avg = float(np.mean(dep['gdp']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %% [markdown]
# **부도율이 평균 이상인 주 중에서**
#
# 30개 중 17개가 평균보다 높은 gdp = 약 0.57%

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_under['gdp'], label='gdp', marker='o', markersize=5)
avg = float(np.mean(dep['gdp']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %% [markdown]
# **부도율이 평균 미만인 주 중에서**
#
# 20개 중 9개가 평균보다 높은 gdp = 약 0.45%

# %% [markdown]
# ##**2) loan_amnt**

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_over['loan_amnt'], label='loan_amnt', marker='o', markersize=5)
avg = float(np.mean(dep['loan_amnt']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_under['loan_amnt'], label='loan_amnt', marker='o', markersize=5)
avg = float(np.mean(dep['loan_amnt']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ##**3) fico**

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_over['fico_range_high'], label='fico_range_high', marker='o', markersize=5)
avg = float(np.mean(dep['fico_range_high']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(30,5))
plt.plot(dep_under['fico_range_high'], label='fico_range_high', marker='o', markersize=5)
avg = float(np.mean(dep['fico_range_high']))
plt.axhline(avg,label='avg', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ##**다른 방식으로 작업 시도**

# %%
dep.describe(percentiles=[.20, .25, .40, .50, .60, .75, .80])
# Out:
#           loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11        gdp
# count     50.000000     50.000000  ...                         50.000000  50.000000
# mean   14172.590400  14172.587417  ...                          0.032945  26.060000
# std      814.145699    814.142244  ...                          0.002785  15.010758
# min    12391.365366  12391.365366  ...                          0.025182   1.000000
# 20%    13539.527280  13539.527280  ...                          0.031045  10.800000
# 25%    13617.135971  13617.135971  ...                          0.031463  13.250000
# 40%    13919.378515  13919.378515  ...                          0.032195  20.600000
# 50%    14110.025705  14110.022412  ...                          0.033231  26.500000
# 60%    14248.068632  14248.068632  ...                          0.033748  31.400000
# 75%    14581.883014  14581.883014  ...                          0.034642  38.750000
# ...

# %%
dep['depvar'].describe(percentiles=[.20, .25, .40, .50, .60, .75, .80])
# Out:
# count    50.000000
# mean      0.156148
# std       0.025395
# min       0.089078
# 20%       0.136432
# 25%       0.139633
# 40%       0.155525
# 50%       0.161873
# 60%       0.166662
# 75%       0.172160
# 80%       0.173739
# max       0.197622
# Name: depvar, dtype: float64

# %%
dep['group'] = ""

# %% [markdown]
# ###**그룹화 진행 : 부도율 백분위 20 단위로 A, B, C, D, E그룹으로 구분**
#
# **A >> E : 부도율 낮은 순에서 높은 순으로**

# %%
dep.loc[dep['depvar'] < 0.136432, 'group'] = 'A'
dep.loc[(dep['depvar'] >= 0.136432) & (dep['depvar'] < 0.155525), 'group'] = 'B'
dep.loc[(dep['depvar'] >= 0.155525) & (dep['depvar'] < 0.166662), 'group'] = 'C'
dep.loc[(dep['depvar'] >= 0.166662) & (dep['depvar'] < 0.173739), 'group'] = 'D'
dep.loc[dep['depvar'] >= 0.173739, 'group'] = 'E'

dep
# Out:
#            loan_amnt   funded_amnt  ...  gdp  group
# state                               ...
# ME(41)  12854.279628  12854.279628  ...   41      A
# VT(35)  13361.317747  13361.317747  ...   35      A
# DC(1)   15375.631369  15375.631369  ...    1      A
# NH(19)  14253.586066  14253.586066  ...   19      A
# OR(24)  13303.357536  13303.357536  ...   24      A
# KS(25)  14209.607451  14209.607451  ...   25      A
# CO(13)  14397.775216  14397.775216  ...   13      A
# SC(46)  14240.295319  14240.295319  ...   46      A
# WA(4)   14719.725415  14719.725415  ...    4      A
# CT(5)   14697.589799  14697.589799  ...    5      A
# MT(42)  13234.713067  13234.713067  ...   42      B
# WV(50)  14586.775031  14586.775031  ...   50      B
# WY(17)  15193.872672  15193.872672  ...   17      B
# WI(27)  13653.594785  13653.594785  ...   27      B
# IL(12)  14813.086061  14813.086061  ...   12      B
# GA(29)  14567.206963  14567.206963  ...   29      B
# ...

# %%
dep_state = dep['group']
dep_state
# Out:
# state
# ME(41)    A
# VT(35)    A
# DC(1)     A
# NH(19)    A
# OR(24)    A
# KS(25)    A
# CO(13)    A
# SC(46)    A
# WA(4)     A
# CT(5)     A
# MT(42)    B
# WV(50)    B
# WY(17)    B
# WI(27)    B
# IL(12)    B
# GA(29)    B
# ND(8)     B
# RI(30)    B
# UT(26)    B
# MA(3)     B
# TX(22)    C
# ID(47)    C
# MN(15)    C
# DE(7)     C
# MI(38)    C
# CA(6)     C
# AZ(40)    C
# VA(18)    C
# OH(28)    C
# HI(16)    C
# PA(21)    D
# AK(9)     D
# NJ(10)    D
# NC(32)    D
# MD(11)    D
# KY(45)    D
# MO(37)    D
# SD(20)    D
# IN(33)    D
# NM(43)    D
# NY(2)     E
# FL(39)    E
# TN(34)    E
# LA(36)    E
# NV(31)    E
# NE(14)    E
# OK(44)    E
# AL(48)    E
# AR(49)    E
# MS(51)    E
# Name: group, dtype: object

# %% [markdown]
# ###**A 그룹**
#
# **총 10개 주**
#
# 서해안 2
#
# 서부 1
#
# 중서부 1
#
# 남부 1
#
# 북동부 5
#
# 기타 0
#
# **ME(41) - 메인, 북동부**
#
# 미국 본토 최북단의 주. 인구는 100만명을 조금 넘으며, 대서양과 캐나다 퀘벡 주에 접하고 있다. 숲이 많은 환경이며 멋진 자연환경으로 유명하다. 날씨는 1년 내내 습하고 여름이 시원하며 겨울이 상당히 춥다. 전체적으로 대도시가 업속 인구밀도가 낮으나, "깡촌"보다는 외곽의 한적한 동네 이미지가 강하다. 미국에서 가장 안전한 주로 뽑히기도 하는 주. 임업이 발달했으며 특산물로 랍스터가 유명하다.
#
# **VT(35) - 버몬트, 북동부**
#
# 캐나다 퀘벡과 접하는 작은 내륙 변방의 주. 인구는 60만명 정도이며, 최대 도시는 벌링턴(Burlington)이다. 겨울에 눈이 많이 내리며 여름은 덥지 않은 편. 메인과 비슷하게 한적한 시골 이미지가 강하다.
#
# **DC(1) - 워싱턴 DC, 북동부**
#
# 인구 70만명의 미국의 수도. 뉴욕, 필라델피아에 이어 연방 수도의 지위를 이어받았다. 메릴랜드, 델라웨어, 버지니아 주 가운데 위치하며 하나의 도시권을 형성하고 있다. 엄밀히 말하면 주는 아니며, 법적으로 준주(Territory)의 지위를 갖고 있다. 미국의 수도로 백악관, 국회의사당 등의 주요 기관들이 (당연히) 이 도시에 위치해 있다.
#
# **NH(19) - 뉴햄프셔, 북동부**
#
# 메인 아래의 작은 주. 역시 인구는 100만명을 조금 넘는다. 최대도시는 맨체스터(Manchester)이다. 전체적으로 내륙에 위치해 있지만, 캐나다 퀘벡 주, 그리고 대서양과 양 끝단이 조금 접하는 모양을 하고 있다. 서북부에 산지가 많아 스키로 유명하다. 민주당 당세가 강한 다른 북동부 주와 달리, 박빙의 승부가 이루어지는 곳. 아이비 리그 중 하나인 다트머스(Dartmouth)대학이 이 주에 위치해 있다.
#
# **OR(24) - 오리건, 서해안**
#
# 주 소비세가 붙지 않아 해외에서 물건을 구매할 때 유용한 주. 최대도시는 포틀랜드이다. 숲과 아름다운 자연으로 잘 알려진 주. 역시 서해안 주 답게 진보적인 분위기이며, 민주당의 당세가 강하다. 살기는 좋은데 놀 거리는 없다는 이미지가 있다. 인구는 4백만명 정도에 소득은 높은 편.
#
# **KS(25)  - 캔서스, 중서부**
#
# 인구 300만명 정도의 중서부 주. 이 근방 지역들이 다들 그렇듯이 상당히 보수적인 편. 주요 산업은 밀 농업이며, 공화당 당세가 강하다
#
# **CO(13) - 콜로라도, 서부**
#
# 미국 국토 한복판에 자리한 주. 인구는 5백만명 정도이며 최대 도시는 덴버이다. 역시 로키 산맥에 걸쳐 있어 평균 해발고도가 높은 편. 언뜻 남쪽에 있어 따뜻할 것 같지만 대륙 한복판에다 고도가 높아 굉장히 춥다. 추위와 눈으로 유명하다. 미국 서부지역의 중심에 자리하여 덴버 공항은 허브 공항으로 이용된다.
#
# **SC(46) - 사우스 캘리포니아, 남부**
#
# 인구 500만명 정도의 남부 주, 주요 도시는 찰스턴(Charleston)과 주도인 콜럼비아(Columbia)이다. 농업, 제조업 등이 두루 발전한 편. 공화당의 당세가 강하나, 남부 주 중에서는 양 당의 세력이 비등한 편.
#
# **WA(4) - 워싱턴, 서해안**
#
# 워싱턴 DC와 종종 헷갈리는 곳. 캐나다 국경과 태평양과 접해있다. 최대도시는 스타벅스의 도시인 시애틀. 마이크로소프트의 본사가 이 주에 소재해 있다. 서해안 주 답게 소득수준은 나쁘지 않으며, 다른 서해안 주들과 같이 기후는 온난하고 살기 좋다. 그래도 남쪽의 캘리포니아와 오리건에 비해서는 다소 추운 편. 민주당 당세가 강한 다소 진보적인 주다. 인구는 7백만명 정도에 소득은 높은 편.
#
# **CT(5) - 코네티컷, 북동부**
#
# 인구 400만명 정도의 동부 주. 최대 도시는 브리지포트(Bridgeport)이다. 아메리카 원주민의 언어로 된 이름이 영어로 변형되면서 생긴 특이한 이름을 갖고 있다. 유명한 인디언 부족인 모히컨의 주 거주지 중 하나였다. 아이비 리그 중 하나인 예일대가 위치한 곳.

# %% [markdown]
# ###**B그룹**
#
# **총 10개 주**
#
# 서해안 0
#
# 서부 3
#
# 중서부 3
#
# 남부 2
#
# 북동부 2
#
# 기타 0
#
# **MT(42) - 몬타나, 서부**
#
# 북서부를 가로지르는 드넓은 면적에 인구는 백만명 뿐인 시골 주. 최대 도시이자 주도는 보이시(Boise)라는 도시다. 모르몬 교의 교세가 강하며 대체로 보수적인 편. 대도시도 없고 소득도 낮은 편이라 시골 이미지가 강하다.
#
# **WV(50) - 웨스트 버지이나, 남부**
#
# 남부 권역 최북단 내륙에 위치한 인구 200만명의 주. 버지니아 주의 북서쪽에 위치하고 있다. 최대도시는 찰스턴. 남북전쟁 시대 버지니아 주로부터 북부로 분리독립했다. 당시 산업구조가 노예가 별로 필요없는 철광업 등이었기 때문. 지금도 석탄, 철광석 등의 광업이 발달했다. 그럼에도 평균소득이 가장 낮은 주 중 하나.
#
# **WY(17) - 와이오밍, 서부**
#
# 인구가 고작 50만명밖에 안 되는 조그마한 주. 물론 땅덩이는 큼직하다. 인구가 50개 주 가운데 (워싱턴DC보다도) 가장 적다. 그래서 미국에서는 "와이오밍에서 온 사람을 본 적이 없다"고 존재하지 않는 주라는 농담을 하기도 하는 주. 공화당이 강세인 지역이며, 의외로 평균 소득수준은 중간 정도. 유명한 옐로스톤 국립공원의 대부분이 이 주에 있다. 이외에 여성 참정권이 처음 인정된 주로 유명하다.
#
# **WI(27) - 위스콘신, 중서부**
#
# 인구 600만명 정도의, 오대호와 접한 여러 주들 중 하나. 북쪽 끄트머리지만 캐나다와는 육지로 접경하지 않는다. 최대도시는 밀워키(Milwaukee). 낙농업이 상당히 발전했다. 진보적인 편이지만 스윙 스테이트로 보기도 한다. 위에서 본 주들과 달리 "시골" 티는 다소 덜 나는 곳. 역시 춥다.
#
# **IL(12) - 일리노이, 중서부**
#
# 인구가 1400만에 달하는 중서부에서는 꽤나 큰 주. 작은 면적이나마 오대호와 접하고 있다. 미국 대도시들의 3축 중 하나를 담당하는 시카고(Chicago)가 일리노이의 최대 도시이다. 시카고 대도시권에 대부분 인구가 생활하고 있으며, 그 외 지역은 대부분이 농업 위주의 산업으로 먹고살고 있다. 인구가 압도적으로 많은 시카고 도시권 덕분에 평균으로 따지면 진보적인 성향이 강한 주다. 중서부 교통의 요지이며 경제규모도 웬만한 국가에 준할 정도로 상당히 크다.
#
# **GA(29) - 조지아, 남부**
#
# 인구 1000만명의 남동부 주, 최대도시는 꽤 유명한 도시인 애틀란타(Atlanta). 다른 남부 주들과 같이 보수적이고 공화당 당세가 강하다. 상당히 종교적이고 보수적인 문화로, 바이블 벨트의 한 축을 담당하고 있다.
#
# **ND(8) - 노스 다코타, 중서부**
#
# 캐나다와 접한 중서부의 작은 주. 인구는 70만명 정도, 면적은 중간 정도로 인구밀도가 상당히 낮다. 위치 덕에 기후는 상당히 추운 편이다. 농업 위주의 산업구조를 가지며, 한때 셰일가스의 발견으로 석유산업이 성장했다. 최대도시는 파고(Fargo). 인지도는 상당히 낮은 편. 공화당 텃세가 강한 주.
#
# **RI(30) - 로드아일랜드, 북동부**
#
# 미국에서 가장 면적이 작은 주. 인구는 100만명으로 면적에 비하면 상당히 많다. 최대 도시는 프로비던스(Providence). 이름이 섬이 들어가지만 섬이 아니다. 주의 이름은 이 주에 속한 정말 조그마한 섬의 이름에서 따온 것 아이비 리그 중 하나인 브라운 대학교가 이 곳에 위치해 있다. 역사적인 장소들이 많아 관광객도 많은 편.
#
# **UT(26) - 유타, 서부**
#
# 미국 서부 가운데의 인구 3백만명의 주. 주요 도시로 솔트레이크 시티가 있다. 록키 산맥이 이 주를 관통하고 있어 평균 해발 고도가 높다. 정치적으로는 공화당이 우세하며, 멋진 자연경관으로 유명하다.
#
# **MA(3) - 메사추세츠, 북동부**
#
# 인구 700만명의 대표적인 동부 주 중 하나. 긴 역사를 가진 지역으로, 주도이자 최대도시는 보스턴(Boston)이다. 이름은 이 지역에 생활하던 원주민 부족의 이름에서 따왔다. 민주당 지지성향이 상당히 강한 지역. 하버드, MIT등의 세계적인 교육기관이 이곳에 위치해 있다.

# %% [markdown]
# ###**C그룹**
#
# **총 10개 주**
#
# 서해안 1
#
# 서부 2
#
# 중서부 3
#
# 남부 2
#
# 북동부 1
#
# 기타 1
#
# **TX(22) - 텍사스, 남부**
#
# 서해안(로스앤젤레스 등)-동해안(뉴욕 등)-중서부(시카고 등)과 함께 미국의 4축을 이루는 큰 주. 면적도 크지만 거의 3000만명에 달하는 인구를 가지고 있다. 다른 남부 주들에 비해서 산업도 발달하고 소득도 높은 편. 그러나 역시 공화당 텃밭이다. 최대도시는 휴스턴이며 댈러스, 포트워스, 주도인 오스틴 등도 꽤나 큰 도시권을 형성하고 있다. 멕시코에 접하고 있다. 백인 비율은 반 정도밖에 안 되며, 히스패닉이 40%, 흑인은 10%, 아시아인은 3%정도를 차지하고 있는 의외로 다양한 인종이 섞여 사는 주. 적도에 가까운 덕분에 NASA 등 우주 관련 산업도 발달했다. "보수적인, 남성적인, 카우보이를 떠올리게 하는" 미국에 관한 선입견 중 하나의 대표지역.
#
# **ID(47) - 아이다호, 서부**
#
# 북서부를 가로지르는 드넓은 면적에 인구는 백만명 뿐인 시골 주. 최대 도시이자 주도는 보이시(Boise)라는 도시다. 모르몬 교의 교세가 강하며 대체로 보수적인 편. 대도시도 없고 소득도 낮은 편이라 시골 이미지가 강하다.
#
# **MN(15) - 미네소타, 중서부**
#
# 오대호에 접한 주로 인구는 600만명 정도, 최대도시는 미니애폴리스(Mineapolis)이다. 백인 비율이 90%로 상당히 높은 지역. 북쪽에 치우친 위치 덕에 굉장히 춥고 눈도 많이 온다. 제조업 등의 산업이 상당히 발전한 편이며 소득도 꽤 높다. 민주당 성향이 상당히 강한 편. 캐나다와 비슷하게 아이스하키의 인기가 높다.
#
# **DE(7) - 델라웨어, 북동부**
#
# 뉴 저지 아래에 위치한 작은 주. 인구는 100만명 정도이며, 주도는 도버(Dover), 최대 도시는 윌밍턴(Wilmington)이다. 기업법이 잘 정비되어 있으며 기업하기 좋은 주로 유명하며, 신용카드 회사들이 이곳에 밀집해 있다. 오리건과 마찬가지로 소비세가 붙지 않는 지역.
#
# **MI(38) - 미시건, 중서부**
#
# 오대호에서 캐나다를 향해 튀어나온 두 개의 반도같은 땅에 위치한 주로, 인구는 1000만명 정도이다. 최대도시는 이전에 자동차산업으로 유명했으나 이제는 몰락한 디트로이트(Detroit)이다. "러스트벨트"의 여러 축 중 하나로 제조업 비중이 높은 편이다. 정치적으로는 민주당이 강세.
#
# **CA(6) - 캘리포니아, 서해안**
#
# 경제규모만으로도 세계 6위권 국가 수준, 미국의 6대 상업도시, 미국 서부의 월 스트리트라고 불리는 금융가가 존재
#
# 주 단위로 따졌을 때 미국에서 가장 영향력이 강한 주들 중 하나. 남북으로 길쭉하기 때문에 기후가 다양하긴 하지만, 대부분의 주요 도시의 기후는 춥지도 덥지도 그다지 습하지도 않은 이상적인 기후를 보여준다. 최대도시는 로스앤젤레스이여, 그 외에 샌 프란시스코도 큰 도시로 유명하다. 인구는 2019년 기준 거의 4천만명에 달하며 호주와 뉴질랜드를 합친 것보다 많다. 면적도 순위권. 그만큼 소득도 높고 생산력도 강해서 떼 놓아도 강대국 노릇을 할 만 한 수준.
#
# **AZ(40) - 애리조나, 서부**
#
# 그랜드 캐니언이 있는 주. 인구 7백만명 정도의 주로 주요 도시는 피닉스가 있으며, 구름이 잘 끼지 않아 엄청난 일조량으로 유명하다. 주 영역의 많은 부분이 시뻘건 사막이다. 여름에 몹시 건조하고 더우며 겨울은 따뜻한 편. 대체로 공화당이 강세인 지역이다.
#
# **VA(18) - 버지니아, 남부**
#
# 인구 900만명 정도의 꽤나 큰 주. 남부에 속하며 최대도시는 버지니아 비치(Virginia Beach)이다. 워싱턴DC와 접한 주들 중 하나. 소득은 웨스트 버지니아에 비하면 높은 편이며, 지리적으로 남부에 속하지만 민주당 지지율이 꽤 높다. 대서양에 접하고 있으며, 농업이 주요 산업이다.
#
# **OH(28) - 오하오이, 중서부**
#
# 오대호에 접하는 또다른 중서부 주로 인구는 1200만명 정도이며, 최대도시는 신시내티(Cincinati)이다. 그 외에도 클리블랜드(Cleveland)와 콜럼버스(Columbus) 두 도시가 각각의 대도시권을 이루고 있다. 대표적인 스윙스테이트로, 대통령 선거 시 주요 격전지 중 하나.
#
# **HI(16) - 하와이, 내륙 밖**
#
# 태평양 한가운의 열도에 위치한 주. 화산섬으로 가끔 화산폭발이 일어나기도 한다. 인구는 150만명 정도이며, 최대도시이자 주도는 호놀룰루(Honolulu)이다. 멋진 자연환경으로 유명하며, 인구 구성은 일본인을 비롯한 동아시아인이 유난히 많은 것으로 유명하다. 알래스카와 함께 미국에게 군사적으로도 매우 중요한 지역. 진주만 해군 기지가 위치해 있다. 관광업이 주 산업의 큰 부분을 차지한다.

# %% [markdown]
# ###**D그룹**
#
# **총 10개 주**
#
# 서해안 0
#
# 서부 1
#
# 중서부 2
#
# 남부 3
#
# 북동부 3
#
# 기타 1
#
# **PA(21) - 펜실베니아, 북동부**
#
# 인구 1300만명 정도의 주로 최대 도시는 동부 의 제2도시 정도로 통하는 필라델피아(Philadelphia)이다. 철강 산업이 유명했던 피츠버그(Pittsburg)도 이 곳의 유명한 도시 중 하나. 여름은 덥고 겨울에는 눈이 많이 오는 기후. 아이비 리그 중 하나인 펜실베니아 대학교(Upenn)가 이 곳에 있다.
#
# **AK(9) - 알래스카, 내륙 밖**
#
# 미국에서 면적이 가장 큰 주. 인구는 70만명 정도, 최대도시는 앵커리지(Anchorage)이다. 캐나다와 태평양에 접하고 있다. 본토와는 상당히 멀리 떨어져 있다. 원래 러시아가 점령했던 땅이었으나, 미국이 구매하여 미국 영토가 되었다. 풍부한 천연자원을 가지고 있고, 미국에게는 상당히 전략적인 지역. 날씨는 당연히 몹시 춥다. 본토와 떨어져 있지만 법적으로는 본토에 속한다. 넓고 인구밀도가 낮아서 경비행기가 주요 교통수단 중 하나.
#
# **NJ(10) - 뉴저지, 북동부**
#
# 인구 1000만명 정도의 대서양에 접한 주. 최대 도시는 뉴어크(Newark)이다. 인구밀도가 미국에서 가장 높다. 북부는 뉴욕 시, 남부는 필라델피아의 권역에 속한 지역으로, 그 쪽으로 출퇴근하는 사람들이 많다. 무언가 자신만의 개성이 없고 뉴욕에 종속된 주 처럼 인식되는 경향이 강하다. 넓게 대서양에 접해있다.
#
# **NC(32) - 노스 캘리포니아, 남부**
#
# 인구 1000만명의 대서양에 접한 남부 주. 최대도시는 샬럿(Charlotte)이다. 농업 및 목축업이 주요 산업이며, 남부 금융의 중심지이기도 하다. 미국은행(Bank of America)의 본사가 위치해 있다. 공화당이 살짝 강세인 스윙 스테이트 중 하나.
#
# **MD(11) - 메릴랜드, 북동부**
#
# 인구 600만명의 동부 주. 워싱턴 DC와 접하고 있다. 최대도시는 볼티모어(Baltimore)이며 주도는 아나폴리스(Anapolis)이다. 미국 해군사관학교가 이곳에 위치해 있다. 동부 중에서도 민주당 당세가 상당히 강한 주 중 하나. 워싱턴 DC 인근이라 중요한 FDA등 정부기관 등이 많다.
#
# **KY(45) - 켄터키, 남부**
#
# 인구 400만 정도의 내륙 주. KFC의 근원지로 유명하다. 가장 큰 도시는 루이빌(Louisville). 농업과 목축업, 특히 담배 산업으로 유명하며, 예전에는 탄광업도 번성했다. 역시 시골 이미지가 강한 주.
#
# **MO(37) - 미주리, 남부**
#
# 인구 600만명 정도의 남부 주. 최대도시는 캔자스 시티(Kansas City)이며, 도시권 인구로는 세인트 루이스(Saint Louis)가 제일 큰 도시다. 칸자스에 있는 캔자스 시티와 다르다. 농업과 목축업이 주 산업이다. 광업 및 대도시권 중심으로 중공업도 발달한 편. 그래도 시골 이미지가 강하다.
#
# **SD(20) - 사우스 다코타, 중서부**
#
# 노스 다코타와 마찬가지로 인구밀도가 낮은 "시골"주이다. 인구는 90만명 정도 되며, 최대도시는 역시 인지도가 낮은 수 폴스(Sioux Falls)이다. 유명한 대통령들의 얼굴이 조각된 러시모어 산이 이 주에 위치해 있으며, 농업 및 관광업이 주 산업이다. 역시 공화당이 우세한 주이다.
#
# **IN(33) - 인디애나, 중서부**
#
# 인구 700만명 정도의 미시건 남부에 접하는 주. 주도이자 최대도시는 인디애나폴리스(Indianapolis)이다. 북부에 위치하고 있지만 비교적 보수적인 성향을 갖는 특이한 주. 러스트벨트와 팜벨트의 경계선에 위치한 주로 제조업과 농업이 주요 산업이다.
#
# **NM(43) - 뉴멕시코, 서부**
#
# 멕시코 국경과 인접한 인구 2백만명 가량의 주. 유명 드라마 <브레이킹 배드>의 배경으로 잘 알려져 있다. 히스패닉계 주민이 인구의 반 정도를 차지하며, 미국의 주들 가운데 가장 높다. 최대 도시는 인구 100만명 정도의 알바커키(Albaquerque)로 인구의 대부분이 대도시 주변에 집중되어 있다. 지형은 이 근처 주들이 그렇듯 사막이 대부분. 히스패닉계 인구가 늘면서 민주당이 강세.

# %% [markdown]
# ###**E그룹**
#
# **총 10개 주**
#
# 서해안 0
#
# 서부 1
#
# 중서부 1
#
# 남부 7
#
# 북동부 1
#
# **NY(2) - 뉴욕, 북동부**
#
# 잘 알려진 미국의 최대도시 뉴욕 시(New York City)는 이 주의 남동부 끝단에 위치해 있다. 뉴욕 주 자체는 뉴욕 시 이외에도 상당히 큰 면적을 차지하고 있으며, 뉴욕 도시권을 제외한 지역을 업스테이트 뉴욕이라 부른다. 북부는 넓게 캐나다와 접하고 있고, 뉴욕 시 도시권은 대서양에 접하고 있다. 인구는 2000만명에 달하며, 평균소득도 미국에서 가장 높은 수준. 상당히 진보적이며 민주당 지지율이 압도적이다.
#
# **FL(39) - 플로리다, 남부**
#
# 대륙 동남단의 반도에 위치한 주로, 주 남부와 북부의 차이가 두드러지는 주. 최대 도시는 마이애미(Miami)이며, 인구는 2000만명에 달하는 꽤 큰 주이다. 북부로 갈수록 전형적인 미국 남부의 분위기이며 종교적이고 보수적이지만, 마이애미 대도시권 등의 남부 지역은 오히려 진보적인 편. 주 소득세가 없는 주로 조세 피난처로 주로 이용된다. 가장 두드러지는 산업은 관광이며, 따뜻한 날씨와 근사한 해변으로 미국을 대표하는 관광지 중 하나. 인구는 백인이 80%정도를 차지하나, 히스패닉 및 스페인 계열의 인종의 비율이 크다. 왠지 기이한 일이 많이 일어나는 주로 유명세를 타는 중.
#
# **TN(34) - 테네시, 남부**
#
# 켄터키 바로 아래에 접하는 길쭉한 주. 최대도시는 멤피스(Memphis), 인구는 700만명 정도 된다. 다른 남부 주들과 비슷하게 공화당 지지세가 강한 주. 총기 규제도 유난히 느슨하다.
#
# **LA(36) - 루이지애나, 남부**
#
# 인구 450만명 정도의 멕시코 만에 접하는 남부 주. 최대도시는 예전 허리케인 카트리나 피해로 유명했던 뉴올리언스(New Orleans). 미국이 프랑스로부터 매입한 "루이지애나"라는 거대한 땅덩이의 최남단 지역이 남아 하나의 주가 되었다. 그런만큼 프랑스 문화의 영향이 큰 곳. 주법도 영미법이 아닌 대륙법의 방식으로 만들어져 있으며, 다른 주들과 다르게 미터법을 사용한다. 농업, 어업, 화학 산업 등이 주요 산업이다.
#
# **NV(31) - 네바다, 서부**
#
# 라스 베가스 덕에 유명한 주. 그 외에는 거의 사막이다. 인구 3백만명 가량. 주 전체가 아무 것도 없는 사막이기 때문에, 라스 베가스를 중심으로 도박 등의 사업을 밀어주어 발전하고 있다. 인구 및 소득 증가율은 빠른 편.
#
# **NE(14) - 네브래스카, 중서부**
#
# 200만명 정도의 인구가 생활하는 미국 한가운데에 위치한 주. 최대도시는 오마하(Omaha)이다. 농업, 그 가운데서도 옥수수를 키우는 농업을 주력 산업으로 하고 있다.
#
# **OK(44)  - 오클라호마, 남부**
#
# 남부에 위치한 인구 400만명 정도의 주. 주도이자 최대도시는 오클라호마 시티(Oklahoma City)이다. 대부분 초원으로 이루어진 지형이며, 농업이 주 산업이지만 석유와 천연가스 자원이 많아 석유산업 의존도도 높다. 블랙 메사(Black Mesa)로 유명한 주. 아메리카 원주민 중 체로키족이 특히 많은 주이다. 남부 답게 보수당 텃밭. 여름에 덥고 겨울에 추운, 게다가 토네이도까지 자주 발생하는 지역.
#
# **AL(48) - 알라바마, 남부**
#
# 인구 500만명 정도의 남부 주. 최대도시는 버밍햄(Birmingham)이다. 제조업, 특히 중공업이 발달했다. 디트로이트 주변이 미제 자동차의 주 생산지라면, 이 곳은 해외 메이커의 자동차 공장이 많은 곳. 미시시피와 비슷하게 멕시코 만에 조금 접하고 있다. 농업 외에도 산업이 발달한 편이지만, 그래도 남부 깡촌 이미지가 있는 편.
#
# **AR(49) - 아칸소, 남부**
#
# 인구 300만명 정도의 남부 주. 최대 도시는 리틀록(Little Rock)이다. 쌀 생산으로 유명하며, 그 외에도 농업이 주 산업이다. 평균소득이 상당히 낮은 편으로 미국에서는 가난한 지역의 이미지가 있다. 공립학교 흑백차별 때문에 일어났던 연방정부 개입사건 "리틀록 사건"으로 유명한 곳. 남부 시골 답게 공화당 지지세가 강하다.
#
# **MS(51) - 미시시피, 남부**
#
# 스펠링이 재밌는 주. s와 p와 i가 많다. 인구는 300만명 정도로 작은 주이며, 최대도시는 잭슨(Jackson)이다. 흑인 인구의 비율이 미국에서 가장 높은 주이자, 평균 소득이 가장 낮은 주. 주 산업은 농업이며, 특히 목화가 유명하다. 습지가 많은 지형이다. 미시시피 강에 걸쳐 있으며, 최남단은 작지만 멕시코 강과 접하는 지역이 있다.

# %% [markdown]
# **<서해안> - 총 3개 주**
#
# "미국"하면 떠오르는 세 종류의 이미지 중 하나를 담당한다. 소득이 높고 경제규모가 크며, 산업이 발달한 주들이다. 서쪽에 태평양을 두어 기후도 주로 온화하다. 당연히 남쪽은 덥고 북쪽은 춥지만 해양성 기후라 그 차이가 크지 않다.
#
# **<서부> - 총 8개 주**
#
# 북부는 숲, 남부는 사막이다. 이 지역의 주들은 대부분 인구가 적고 면적이 크며, 허허벌판이 많고 대도시가 없다. 두루 따뜻한 서해안과 달리, 북부는 굉장히 춥고 남부는 굉장히 더운 극단적인 기후 격차를 보인다. 북부는 아메리카 원주민의 비율이 많은 편이고, 남부는 멕시코와 접하여 히스패닉 계열의 인구가 많은 편.
#
#
# **<중서부> - 총 10(11)개 주**
#
# 중서부의 주들은 오대호 주변 러스트벨트에 속한 제조업 위주의 주들과, 외곽의 농업 위주의 주들로 나뉘어진다. 대부분의 대도시는 오대호에 접한 주들(위스콘신, 일리노이, 미시건, 오하이오)에 위치해 있으며, 이 지역이 경제규모나 인구 등의 측면에서 외곽지역의 주들을 압도한다. 외곽 주들은 농업이 주 산업이며 서부 주들 못지 않게 인구밀도가 낮은 지역.
#
# **<남부> - 총 15개 주**
#
# 상당히 보수적이고 기독교 교세가 강한 주들이 남쪽에 모여있다. 미국 남북전쟁 시 노예제에 찬성했던 주들이 대부분을 차지한다. 대도시는 동해안에 접한 주들이나 텍사스에 주로 분포하며, **나머지는 주로 농업 위주의 주들이다. 대체로 흑인 인구 비율이 높은 편.**
#
# **<북동부> - 총 12개 주**
#
# 가장 처음 유럽인들이 이주해 온 "오리지널" 미국이다. 인구는 많지만 각 주의 면적은 상당히 좁다. 많은 대도시들이 북동부에 모여 있으며, 대부분의 도시가 300~400년에 달하는 역사를 자랑한다. 반면 대부분의 지역이 도시화되어 정치적인 성향은 대체로 진보적인 편이다. 긴 역사 덕분에 미국의 유명한 대학들은 거의 이 지역에 포진해 있다. 다른 지역에 비해서 금융업 등의 산업이 강세.
#
# **<기타> - 총 2개 주**

# %%
states = pd.DataFrame({'서해안': [2/3, 0/3, 1/3, 0/3, 0/3],
                      '서부' : [1/8, 3/8, 2/8, 1/8, 1/8],
                      '중서부' : [1/10, 3/10, 3/10, 2/10 , 1/10],
                      '남부' : [1/15, 2/15, 2/15, 3/15, 7/15],
                      '북동부' : [5/12, 2/12, 1/12, 3/12, 1/12],
                      '기타': [0/2, 0/2, 1/2, 1/2, 0/2]}, index = ['A', 'B', 'C', 'D', 'E'])
states
# Out:
#         서해안     서부  중서부        남부       북동부   기타
# A  0.666667  0.125  0.1  0.066667  0.416667  0.0
# B  0.000000  0.375  0.3  0.133333  0.166667  0.0
# C  0.333333  0.250  0.3  0.133333  0.083333  0.5
# D  0.000000  0.125  0.2  0.200000  0.250000  0.5
# E  0.000000  0.125  0.1  0.466667  0.083333  0.0

# %% [markdown]
# 남부의 비중은 E그룹에서 매우 높게 나타남
#
# 서해안, 북동부의 비중은 A그룹에서 매우 높게 나타남

# %% [markdown]
# ###**백분위에 따라 부도율 그룹을 5개로 그룹화 진행**

# %%
group = dep.groupby(['group']).mean()
group
# Out:
#           loan_amnt   funded_amnt  ...  mths_since_recent_revol_delinq11   gdp
# group                              ...
# A      14141.316555  14141.316555  ...                          0.032537  21.3
# B      14257.331565  14257.331565  ...                          0.031897  24.4
# C      14217.250720  14217.237470  ...                          0.033143  23.7
# D      14461.524416  14461.523991  ...                          0.033992  26.1
# E      13785.528746  13785.527507  ...                          0.033157  34.8
#
# [5 rows x 283 columns]

# %%
#부도율 평균
plt.figure(figsize=(10,5))
plt.plot(group['depvar'], label='depvar', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#이자율 평균
plt.figure(figsize=(10,5))
plt.plot(group['int_rate'], label='int_rate', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#gdp 순위 평균
plt.figure(figsize=(10,5))
plt.plot(group['gdp'], label='gdp', marker='o', markersize=5)
plt.legend()
plt.show()

# %% [markdown]
# ###**A그룹과 E그룹의 값이 최대/최소 OR 최소/최대인 경우만 뽑아봄 (그룹의 특징 찾기)**

# %%
#acc_now_delinq에서는 부도율이 가장 높은 그룹이 가장 높은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['acc_now_delinq'], label='acc_now_delinq', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#dti에서는 부도율이 가장 높은 그룹이 가장 높은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['dti'], label='dti', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#tot_cur_bal에서는 부도율이 가장 높은 그룹이 가장 낮은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['tot_cur_bal'], label='tot_cur_bal', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#revol_bal에서는 부도율이 가장 높은 그룹이 가장 낮은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['revol_bal'], label='revol_bal', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#annual_inc에서는 부도율이 가장 높은 그룹이 가장 낮은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['annual_inc'], label='annual_inc', marker='o', markersize=5)
plt.legend()
plt.show()

# %% [markdown]
# ###**부도율이 가장 높은 그룹이 특이한 값/특징적인 값을 가지는 경우를 뽑아봄**

# %%
#loan_amnt에서는 부도율이 가장 높은 그룹이 가장 낮은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['loan_amnt'], label='loan_amnt', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#delinq_2yrs에서는 부도율이 가장 높은 그룹이 가장 높은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['delinq_2yrs'], label='delinq_2yrs', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
#installment에서는 부도율이 가장 높은 그룹이 가장 낮은 값을 보임
plt.figure(figsize=(10,5))
plt.plot(group['installment'], label='installment', marker='o', markersize=5)
plt.legend()
plt.show()

# %% [markdown]
# **아래 내용은 큰 의미 없음**

# %%
plt.figure(figsize=(10,5))
plt.plot(group['fico_range_high'], label='fico_range_high', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(group['pub_rec'], label='pub_rec', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(group['open_acc'], label='open_acc', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(group['total_acc'], label='total_acc', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(group['delinq_amnt'], label='delinq_amnt', marker='o', markersize=5)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(group['tax_liens'], label='tax_liens', marker='o', markersize=5)
plt.legend()
plt.show()
